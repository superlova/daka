# %%
#!mkdir drive/My\ Drive/trained_models
#!cp mnist_lenet_1.h5 mnist_lenet_2.h5 drive/My\ Drive/trained_models -i
# !ls drive/My\ Drive/trained_models
# Out:
# mnist_lenet_1.h5  mnist_lenet_2.h5

# %%
# !pip install tensorflow-gpu

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models

# %%
# !pip show protobuf
# !nvcc --version
# print(tf.__version__)
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

# %%
tf.test.is_gpu_available()
# Out:
# True

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                36928
# ...

# %%
model2 = models.Sequential()
model2.add(layers.Conv2D(
    filters=6, # 输出通道为6个
    kernel_size=5, # 窗口大小5*5
    activation='sigmoid', #激活函数
    input_shape=(28, 28, 1) # 输入图片规格，包括长、款、通道
))
model2.add(layers.MaxPool2D(pool_size=2, strides=2))

model2.add(layers.Conv2D(
    filters=16,
    activation='sigmoid',
    kernel_size=5
))
model2.add(layers.MaxPool2D(pool_size=2, strides=2))

model2.add(layers.Flatten())
model2.add(layers.Dense(120, activation='sigmoid'))
model2.add(layers.Dense(84, activation='sigmoid'))
model2.add(layers.Dense(10, activation='sigmoid'))

# %%
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 24, 24, 6)         156
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 6)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 16)          2416
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 120)               30840
# _________________________________________________________________
# dense_3 (Dense)              (None, 84)                10164
# ...

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype('float32') / 255
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
model.compile(optimizer='rmsprop',
loss='categorical_crossentropy',
metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 9s 151us/sample - loss: 0.1803 - accuracy: 0.9443
# Epoch 2/5
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.0487 - accuracy: 0.9851
# Epoch 3/5
# 60000/60000 [==============================] - 4s 67us/sample - loss: 0.0351 - accuracy: 0.9895
# Epoch 4/5
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.0272 - accuracy: 0.9922
# Epoch 5/5
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.0207 - accuracy: 0.9937

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
test_acc
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
model.save('mnist_lenet_1.h5')

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype('float32') / 255
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
model2.compile(
    optimizer='rmsprop',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
model2.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 5s 79us/sample - loss: 1.1066 - accuracy: 0.6601
# Epoch 2/5
# 60000/60000 [==============================] - 4s 67us/sample - loss: 0.2526 - accuracy: 0.9248
# Epoch 3/5
# 60000/60000 [==============================] - 4s 67us/sample - loss: 0.1462 - accuracy: 0.9551
# Epoch 4/5
# 60000/60000 [==============================] - 4s 63us/sample - loss: 0.1074 - accuracy: 0.9665
# Epoch 5/5
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.0888 - accuracy: 0.9722

# %%
test_loss, test_acc = model2.evaluate(test_images, test_labels)
test_acc
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
model2.save('mnist_lenet_2.h5')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
