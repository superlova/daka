# %%
import pandas as pd
import numpy as np
import os, sys

# %%
datasets = './datasets/titanic'
os.listdir(datasets)
# Out:
# ['gender_submission.csv', 'test.csv', 'train.csv']

# %%
train_file = os.path.join(datasets, 'train.csv')
test_file = os.path.join(datasets, 'test.csv')
gender_file = os.path.join(datasets, 'gender_submission.csv')

# %%
df_train = pd.read_csv(train_file, sep=',', encoding='u8')
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 一共891个乘客信息，每个乘客信息包含乘客ID、是否幸存、乘客仓位级别、姓名、性别、年龄、兄弟姐妹个数、直系亲属个数、船票信息、票价、客舱、登船窗口信息。

# %%
df_train_chunked = pd.read_csv(train_file, chunksize=1000)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', '仓位级别', 'Name', 'Sex', 'Age', '兄弟姐妹个数',
#        '直系亲属个数', 'Ticket', 'Fare', '客舱', '登船窗口'],
#       dtype='object')

# %%
df_train.rename(columns={
    'SibSp' : '兄弟姐妹个数',
    'Parch' : '直系亲属个数',
    'Cabin' : '客舱',
    'Embarked' : '登船窗口',
    'Pclass' : '仓位级别',
}, inplace = True)
df_train
# Out:
#      PassengerId  Survived  仓位级别  \
# 0              1         0     3
# 1              2         1     1
# 2              3         1     3
# 3              4         1     1
# 4              5         0     3
# ..           ...       ...   ...
# 886          887         0     2
# 887          888         1     1
# 888          889         0     3
# 889          890         1     1
# 890          891         0     3
#
#                                                   Name     Sex   Age  兄弟姐妹个数  \
# 0                              Braund, Mr. Owen Harris    male  22.0       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                             Allen, Mr. William Henry    male  35.0       0
# ..                                                 ...     ...   ...     ...
# ...

# %%
df_train.isnull()
# Out:
#      PassengerId  Survived   仓位级别   Name    Sex    Age  兄弟姐妹个数  直系亲属个数  \
# 0          False     False  False  False  False  False   False   False
# 1          False     False  False  False  False  False   False   False
# 2          False     False  False  False  False  False   False   False
# 3          False     False  False  False  False  False   False   False
# 4          False     False  False  False  False  False   False   False
# ..           ...       ...    ...    ...    ...    ...     ...     ...
# 886        False     False  False  False  False  False   False   False
# 887        False     False  False  False  False  False   False   False
# 888        False     False  False  False  False   True   False   False
# 889        False     False  False  False  False  False   False   False
# 890        False     False  False  False  False  False   False   False
#
#      Ticket   Fare     客舱   登船窗口
# 0     False  False   True  False
# 1     False  False  False  False
# ...

# %% [markdown]
# 按票价和年龄两列进行综合排序（降序排列），

# %%
df_train.sort_values(by=['Fare', 'Age'], ascending=False)
# Out:
#      PassengerId  Survived  仓位级别                                Name     Sex  \
# 679          680         1     1  Cardeza, Mr. Thomas Drake Martinez    male
# 258          259         1     1                    Ward, Miss. Anna  female
# 737          738         1     1              Lesurer, Mr. Gustave J    male
# 438          439         0     1                   Fortune, Mr. Mark    male
# 341          342         1     1      Fortune, Miss. Alice Elizabeth  female
# ..           ...       ...   ...                                 ...     ...
# 481          482         0     2    Frost, Mr. Anthony Wood "Archie"    male
# 633          634         0     1       Parr, Mr. William Henry Marsh    male
# 674          675         0     2          Watson, Mr. Ennis Hastings    male
# 732          733         0     2                Knight, Mr. Robert J    male
# 815          816         0     1                    Fry, Mr. Richard    male
#
# ...

# %% [markdown]
# 通过泰坦尼克号数据如何计算出在船上最大的家族有多少人？

# %%
max(df_train['兄弟姐妹个数'] + df_train['直系亲属个数'])
# Out:
# 10

# %% [markdown]
# 分别看看泰坦尼克号数据集中 票价、父母子女 这列数据的基本统计数据

# %%
df_train['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df_train['直系亲属个数'].describe()
# Out:
# count    891.000000
# mean       0.381594
# std        0.806057
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        6.000000
# Name: 直系亲属个数, dtype: float64

# %% [markdown]
# 读取test.csv

# %%
df_test = pd.read_csv(test_file)
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# 添加多余的一列，然后删除

# %%
df_test['a'] = False
df_test.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked      a
# 0      0  330911  7.8292   NaN        Q  False
# 1      0  363272  7.0000   NaN        S  False
# 2      0  240276  9.6875   NaN        Q  False

# %%
df_test.drop(columns=['a'], inplace=True)
df_test.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %% [markdown]
# 将['PassengerId','Name','Age','Ticket']这几个列元素隐藏，只观察其他几个列元素

# %%
df_train.drop(columns=['PassengerId','Name','Age','Ticket']).head(3)
# Out:
#    Survived  仓位级别     Sex  兄弟姐妹个数  直系亲属个数     Fare   客舱 登船窗口
# 0         0     3    male       1       0   7.2500  NaN    S
# 1         1     1  female       1       0  71.2833  C85    C
# 2         1     3  female       0       0   7.9250  NaN    S

# %% [markdown]
#  以"Age"为条件，将年龄在10岁以上和50岁以下的乘客信息显示出来，并将这个数据命名为midage

# %%
df_train_midage = df_train[(df_train['Age'] > 10) & (df_train['Age'] < 50)]
df_train_midage
# Out:
#      PassengerId  Survived  仓位级别  \
# 0              1         0     3
# 1              2         1     1
# 2              3         1     3
# 3              4         1     1
# 4              5         0     3
# ..           ...       ...   ...
# 885          886         0     3
# 886          887         0     2
# 887          888         1     1
# 889          890         1     1
# 890          891         0     3
#
#                                                   Name     Sex   Age  兄弟姐妹个数  \
# 0                              Braund, Mr. Owen Harris    male  22.0       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                             Allen, Mr. William Henry    male  35.0       0
# ..                                                 ...     ...   ...     ...
# ...

# %% [markdown]
# 将midage的数据中第100行的"Pclass"和"Sex"的数据显示出来

# %%
df_train_midage.reset_index(drop=True, inplace=True)
df_train_midage
# Out:
#      PassengerId  Survived  仓位级别  \
# 0              1         0     3
# 1              2         1     1
# 2              3         1     3
# 3              4         1     1
# 4              5         0     3
# ..           ...       ...   ...
# 571          886         0     3
# 572          887         0     2
# 573          888         1     1
# 574          890         1     1
# 575          891         0     3
#
#                                                   Name     Sex   Age  兄弟姐妹个数  \
# 0                              Braund, Mr. Owen Harris    male  22.0       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                             Allen, Mr. William Henry    male  35.0       0
# ..                                                 ...     ...   ...     ...
# ...

# %%
df_train_midage.loc[[100], ['仓位级别', 'Sex']]
# Out:
#      仓位级别   Sex
# 100     2  male

# %% [markdown]
# 使用loc方法将midage的数据中第100，105，108行的"Pclass"，"Name"和"Sex"的数据显示出来

# %%
df_train_midage.loc[[100,105,108],['仓位级别','Name','Sex']]
# Out:
#      仓位级别                               Name   Sex
# 100     2  Byles, Rev. Thomas Roussel Davids  male
# 105     3           Cribb, Mr. John Hatfield  male
# 108     3                    Calic, Mr. Jovo  male

# %% [markdown]
# 使用iloc方法将midage的数据中第100，105，108行的"Pclass"，"Name"和"Sex"的数据显示出来

# %%
df_train_midage.iloc[[100,105,108],[2,3,4]]
# Out:
#      仓位级别                               Name   Sex
# 100     2  Byles, Rev. Thomas Roussel Davids  male
# 105     3           Cribb, Mr. John Hatfield  male
# 108     3                    Calic, Mr. Jovo  male

# %%
df_train.to_csv("df_train.csv")
